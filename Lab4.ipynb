# %% [markdown]
# <a href="https://colab.research.google.com/github/tofighi/ITM760/blob/main/Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Association Rule Mining
# In this lab, you will get familiar with `Apriori` algorithm and `association rule mining` in Python. You will implement the Apriori algorithm in python and generate rules accordingly. At the end of the lab, you should be able to:
# - Perform basket analysis
# - Run Apriori to discover frequent itemsets
# - Discover association rules
#
# A more comprehensive code exists [here](https://www.kaggle.com/roshansharma/market-basket-analysis/notebook)

# %%
# !pip install apyori
# !wget -q https://raw.githubusercontent.com/tofighi/ITM760/main/dataset/store_data.csv
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=ad2fda52d39ba7b317c17d3816d298145f006143f3d0b08bab64455c6ffe9b75
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# ...

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd  
from apyori import apriori  

store_data = pd.read_csv('store_data.csv')  
store_data.head()  
store_data = pd.read_csv('store_data.csv', header=None)  
store_data.head()
# Out:
#               0          1           2   ...               17       18         19
# 0         shrimp    almonds     avocado  ...  frozen smoothie  spinach  olive oil
# 1        burgers  meatballs        eggs  ...              NaN      NaN        NaN
# 2        chutney        NaN         NaN  ...              NaN      NaN        NaN
# 3         turkey    avocado         NaN  ...              NaN      NaN        NaN
# 4  mineral water       milk  energy bar  ...              NaN      NaN        NaN
#
# [5 rows x 20 columns]

# %%
store_data.shape
# Out:
# (7501, 20)

# %%
#preprocessing 
number_of_records = store_data.shape[0]
max_basket_items = store_data.shape [1]

records = []  
for i in range(0, number_of_records):
  records.append([str(store_data.values[i,j]) for j in range(0, max_basket_items)])
#records

# %% [markdown]
# # Applying Apriori

# %%
#Applying Apriori
association_rules = apriori(records, min_support=0.0045, min_confidence=0.75, min_length=2)  
association_results = list(association_rules)  
for item in association_results:
    print(item[0])
# Out:
# frozenset({'nan'})
# frozenset({'nan', 'almonds'})
# frozenset({'nan', 'antioxydant juice'})
# frozenset({'nan', 'asparagus'})
# frozenset({'nan', 'avocado'})
# frozenset({'nan', 'babies food'})
# frozenset({'bacon', 'nan'})
# frozenset({'nan', 'barbecue sauce'})
# frozenset({'nan', 'black tea'})
# frozenset({'nan', 'blueberries'})
# frozenset({'nan', 'body spray'})
# frozenset({'nan', 'brownies'})
# frozenset({'nan', 'bug spray'})
# frozenset({'nan', 'burger sauce'})
# frozenset({'nan', 'burgers'})
# frozenset({'nan', 'butter'})
# frozenset({'nan', 'cake'})
# frozenset({'nan', 'candy bars'})
# frozenset({'carrots', 'nan'})
# frozenset({'nan', 'cauliflower'})
# frozenset({'nan', 'cereals'})
# frozenset({'nan', 'champagne'})
# frozenset({'nan', 'chicken'})
# frozenset({'nan', 'chili'})
# frozenset({'nan', 'chocolate'})
# frozenset({'nan', 'cider'})
# frozenset({'nan', 'clothes accessories'})
# frozenset({'nan', 'cookies'})
# frozenset({'nan', 'cooking oil'})
# ...

# %%
#The following script displays the rule, the support, the confidence, each rule in a more clear way:
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    if len(items) >1:
        print("Rule: " + items[0] + " -> " + items[1])
        #second index of the inner list
        print("Support: " + str(item[1]))
        #third index of the list located at 0th
        #of the third index of the inner list
        print("Confidence: " + str(item[2][0][2]))
        print("=====================================")
# Out:
# Rule: nan -> almonds
# Support: 0.020263964804692707
# Confidence: 0.9934640522875817
# ...
# Rule: nan -> antioxydant juice
# Support: 0.008798826823090255
# Confidence: 0.9850746268656716
# ...
# Rule: nan -> asparagus
# Support: 0.004666044527396347
# Confidence: 1.0
# ...
# Rule: nan -> avocado
# Support: 0.03319557392347687
# Confidence: 0.996
# ...
# Rule: nan -> babies food
# Support: 0.004532728969470737
# Confidence: 1.0
# ...
# Rule: bacon -> nan
# Support: 0.008665511265164644
# Confidence: 1.0
# ...
# Rule: nan -> barbecue sauce
# Support: 0.010798560191974404
# Confidence: 1.0
# ...
# Rule: nan -> black tea
# Support: 0.014264764698040262
# Confidence: 1.0
# ...
# Rule: nan -> blueberries
# Support: 0.009198773496867084
# Confidence: 1.0
# ...
# Rule: nan -> body spray
# Support: 0.011465137981602452
# Confidence: 1.0
# ...
# Rule: nan -> brownies
# Support: 0.03372883615517931
# Confidence: 1.0
# ...
# Rule: nan -> bug spray
# Support: 0.008665511265164644
# Confidence: 1.0
# ...
# Rule: nan -> burger sauce
# Support: 0.005865884548726837
# ...
